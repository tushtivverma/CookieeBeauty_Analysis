# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Best_selling_Products.csv')

# %%
df
# Out:
#     Unnamed: 0                      Unnamed: 1  Unnamed: 2 Time period  \
# 0          NaN                       Item name  Rank limit     row_num
# 1          1.0    Valentina Lip and Cheek Tint          20           1
# 2          2.0          24K rose Lip Oil Gloss          20           2
# 3          3.0                           Woody          20           3
# 4          4.0                           Lucid          20           4
# 5          5.0                       Moonlight          20           5
# 6          6.0                            Ruby          20           6
# 7          7.0          Lash & Brow Growth Oil          20           7
# 8          8.0                           Bills          20           8
# 9          9.0                         Sangria          20           9
# 10        10.0                       Bubblegum          20          10
# 11        11.0                        Euphoria          20          11
# ...

# %%
column_name = df.columns

# %%
column_name
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Time period',
#        'Current period', 'Unnamed: 5'],
#       dtype='object')

# %%
# Set the second row as column names
df.columns = df.iloc[0]  # Set the second row as the header

df = df[1:].reset_index(drop=True)

# %%
df
# Out:
# 0    NaN                       Item name Rank limit row_num Gross sales rank
# 0    1.0    Valentina Lip and Cheek Tint         20       1     41572.5    1
# 1    2.0          24K rose Lip Oil Gloss         20       2    38743.75    2
# 2    3.0                           Woody         20       3      32825.    3
# 3    4.0                           Lucid         20       4      30940.    4
# 4    5.0                       Moonlight         20       5      29765.    5
# 5    6.0                            Ruby         20       6      29170.    6
# 6    7.0          Lash & Brow Growth Oil         20       7      28044.    7
# 7    8.0                           Bills         20       8      24605.    8
# 8    9.0                         Sangria         20       9      22880.    9
# 9   10.0                       Bubblegum         20      10      20550.   10
# 10  11.0                        Euphoria         20      11      20065.   11
# ...

# %%
new_col_name = df.columns

# %%
new_col_name
# Out:
# Index([nan, 'Item name', 'Rank limit', 'row_num', 'Gross sales', 'rank'], dtype='object', name=0)

# %%
# Drop columns that are not necessary
df = df.drop(columns = ['Rank limit', 'row_num'])

# %%
# Drop the column with NaN as it's header
df = df.loc[:, df.columns.notna()]

# %%
df
# Out:
# 0                        Item name Gross sales rank
# 0     Valentina Lip and Cheek Tint     41572.5    1
# 1           24K rose Lip Oil Gloss    38743.75    2
# 2                            Woody      32825.    3
# 3                            Lucid      30940.    4
# 4                        Moonlight      29765.    5
# 5                             Ruby      29170.    6
# 6           Lash & Brow Growth Oil      28044.    7
# 7                            Bills      24605.    8
# 8                          Sangria      22880.    9
# 9                        Bubblegum      20550.   10
# 10                        Euphoria      20065.   11
# 11                           Nudes      18870.   12
# 12                          Dinero      18380.   13
# 13                        Body Oil      16881.   14
# 14         Lip and Eye mask Bundle      14600.   15
# 15  Brown Sugar Lip and Cheek Tint    14370.75   16
# 16                    Heart Mirror    14318.75   17
# ...
